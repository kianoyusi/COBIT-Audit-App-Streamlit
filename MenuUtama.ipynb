# %%
#### ===============================================
# File: MenuUtama.ipynb
# Ini adalah file utama yang Anda jalankan
# ===============================================

print("================================================================")
print("   PROGRAM EVALUASI TATA KELOLA TI (COBIT) - TUGAS UTS AUSI")
print("      Studi Kasus: Sistem Informasi Marketplace Tokopedia")
print("================================================================")

print(" Nama Kelompok:")
print("1. Nafar Ja'far Ashidiqi : 202353135")
print("2. Selamet Ahmad Faisal  : 202353103")
print("3. Endhito Hafiz Meifaza : 202353148")

while True:
    print("\n--- MENU UTAMA ---")
    print("Silakan pilih domain yang ingin dievaluasi:")
    print("1. EDM (Evaluate, Direct and Monitor)")
    print("2. APO (Align, Plan and Organize)")
    print("3. BAI (Build, Acquire and Implement) - (TODO)")
    print("4. DSS (Deliver, Service and Support) - (TODO)")
    print("5. MEA (Monitor, Evaluate and Assess) - (TODO)")
    print("6. Keluar dari Program")
    
    pilihan = input("Masukkan pilihan Anda (1-6): ")
    
    print("\n") # Beri spasi
    
    if pilihan == '1':
        # Perintah ini akan menjalankan SEMUA kode di file Domain_EDM.ipynb
        # %run Domain_EDM.ipynb 
        
    elif pilihan == '2':
        # Perintah ini akan menjalankan SEMUA kode di file Domain_APO.ipynb
        # %run Domain_APO.ipynb 
        
    elif pilihan == '3':
        # Perintah ini akan menjalankan SEMUA kode di file Domain_BAI.ipynb
        # %run Domain_BAI.ipynb  
        
    elif pilihan == '4':
        # Perintah ini akan menjalankan SEMUA kode di file Domain_DSS.ipynb
        # %run Domain_DSS.ipynb  
        
    elif pilihan == '5':
        # Perintah ini akan menjalankan SEMUA kode di file Domain_MEA.ipynb
        # %run Domain_MEA.ipynb  
        
    elif pilihan == '6':
        break # Keluar dari loop while
        
    else:
        print("Pilihan tidak valid. Silakan masukkan angka antara 1 sampai 6.")
# Out:
# ...
#    PROGRAM EVALUASI TATA KELOLA TI (COBIT) - TUGAS UTS AUSI
#       Studi Kasus: Sistem Informasi Marketplace Tokopedia
# ...
#  Nama Kelompok:
# 1. Nafar Ja'far Ashidiqi : 202353135
# 2. Selamet Ahmad Faisal  : 202353103
# 3. Endhito Hafiz Meifaza : 202353148
#
# --- MENU UTAMA ---
# Silakan pilih domain yang ingin dievaluasi:
# 1. EDM (Evaluate, Direct and Monitor)
# 2. APO (Align, Plan and Organize)
# 3. BAI (Build, Acquire and Implement) - (TODO)
# 4. DSS (Deliver, Service and Support) - (TODO)
# 5. MEA (Monitor, Evaluate and Assess) - (TODO)
# 6. Keluar dari Program
# Masukkan pilihan Anda (1-6):  1
# --- Memuat Modul Domain EDM ---
# Memulai Evaluasi Domain: EDM (Evaluate, Direct and Monitor)
#
# --- Panduan Penilaian (Skala Likert) ---
# 1: Sangat Tidak Setuju / Sangat Buruk
# 2: Tidak Setuju / Buruk
# 3: Netral
# 4: Setuju / Baik
# 5: Sangat Setuju / Sangat Baik
# ------------------------------------------
#
# ...
